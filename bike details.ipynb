# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
#what is the range of selling prices in the dataset.
selling_price_range = df['selling_price'].max() - df['selling_price'].min()
print(selling_price_range)
# Out:
# 755000

# %%
# what is the median selling price for bikes in the dataset?
median_selling_price = df['selling_price'].median()
print(median_selling_price)
# Out:
# 45000.0

# %%
# what is the most common seller type?
most_common_seller_type = df['seller_type'].mode()[0]
most_common_seller_type
# Out:
# 'Individual'

# %%
# How many bikes have driven more than 50,000 ,kilometers?
# Filter the dataset for bikes that have driven more than 50,000 kilometers
bikes_over_50000 = df[df['km_driven'] > 50000]
count = len(bikes_over_50000)
print(count)
# Out:
# 170

# %%
# what is the average km_driven value for each ownership type?
avg_km_by_owner = df.groupby('owner')['km_driven'].mean()
avg_km_by_owner
# Out:
# owner
# 1st owner     32816.583333
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
# 6.  what proportion of bikes are from the year 2015 or older?
# count the total numbers of bike
total_bike = len(df)

# count the no. of bikes from 2015 or older
bikes_2015_or_older = len(df[df['year'] <= 2015])

# Calculate the proportion
proportion = bikes_2015_or_older/total_bike
print(proportion)
# Out:
# 0.5664467483506126

# %%
# 7. what is the trend of missing values across the dataset?
# Calculate the number of missing values in each column
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
# Calculate the percentage of missing values in each column
missing_values_percentage = (df.isnull().sum() / len(df)) * 100
missing_values_percentage
# Out:
# name                  0.000000
# selling_price         0.000000
# year                  0.000000
# seller_type           0.000000
# owner                 0.000000
# km_driven             0.000000
# ex_showroom_price    40.999057
# dtype: float64

# %%
missing_values_trend = pd.DataFrame({'missing values count':missing_values_count,
                                     'missing values percentage': missing_values_percentage})
print(missing_values_trend)
# Out:
#                    missing values count  missing values percentage
# name                                  0                   0.000000
# selling_price                         0                   0.000000
# year                                  0                   0.000000
# seller_type                           0                   0.000000
# owner                                 0                   0.000000
# km_driven                             0                   0.000000
# ex_showroom_price                   435                  40.999057

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
# 8. what is the highest ex_showroom_price recorded, and for which bike ?
# Find the row with the highest ex_showroom_price
highest_price_row = df.loc[df['ex_showroom_price'].idxmax()]

# Extract the bike name and the highest price
bike_name = highest_price_row['name']
highest_price = highest_price_row['ex_showroom_price']

print(f"The highest ex_showroom_price is {highest_price} for the bike: {bike_name}.")
# Out:
# The highest ex_showroom_price is 1278000.0 for the bike: Harley-Davidson Street Bob.

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
# 9. what is the total number of bikes listed by each seller type?
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual    1055
# Dealer           6
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df['owner'].unique()
# Out:
# array(['1st owner', '2nd owner', '3rd owner', '4th owner'], dtype=object)

# %%
# 10. what is the relationship between selling_price and ,km_driven for first-owner bikes?
first_owner_bikes = df[df['owner'] == '1st owner']

#Calculate the correlation between selling_price and km_driven
correlation = first_owner_bikes['selling_price'].corr(first_owner_bikes['km_driven'])
print(f"Correlation between Selling Price and KM Driven for First-Owner Bikes: {correlation}")
# Out:
# Correlation between Selling Price and KM Driven for First-Owner Bikes: -0.24348174844965703

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
#11. Identify and remove outliers in the km_driven column using the ICR method ? 
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 -Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_df = df[(df['km_driven'] >= lower_bound) & (df['km_driven'] <= upper_bound)]

print(filtered_df)
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1054                     Hero  CBZ Xtreme          20000  2010  Individual
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
# 12. Perform a bivariate analysis to visualize the relationship between year and selling_price
plt.figure(figsize = (12,6))
sns.barplot(x = 'year', y = 'selling_price', data = df, palette = 'viridis')
plt.title("Selling Price Vs Year")
plt.xlabel('Year')
plt.ylabel("Selling Price")
plt.xticks(rotation = 90)
plt.show()

# %%
# INSIGHTS 
# as the year is increasing the selling price of the bike is also increasing

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = df, x = 'year',y = 'selling_price', hue = 'owner', palette = 'viridis')
plt.title("Scatter Plot: Year vs Selling Price")
plt.xlabel("year")
plt.ylabel("Selling Price")
plt.show()

# %%
# insight >>> here we can see that there are first owners bike are more .

# %%
plt.figure(figsize =(12,6))
sns.boxplot(data = df , x = 'year', y = 'selling_price' , palette = 'Set2')
plt.title('Box Plot: Year vs Selling Price')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.xticks(rotation = 90)
plt.show()

# %%
# insights >>> here we can see there are outliers present for different years

# %%
# 13. what is the average depreciation in selling price based on the bike's age (current year - manufacturing
#year) ?

current_year = 2025
df['bikes_age'] = current_year - df['year']

avg_price_by_age = df.groupby('bikes_age')['selling_price'].mean().reset_index()

avg_price_by_age['depriciation'] = avg_price_by_age['selling_price'].diff()
print(avg_price_by_age)
# Out:
#     bikes_age  selling_price   depriciation
# 0           5  183333.333333            NaN
# 1           6  119689.511628  -63643.821705
# 2           7   87660.374046  -32029.137582
# 3           8   78894.736842   -8765.637204
# 4           9   58469.018692  -20425.718151
# 5          10   56500.000000   -1969.018692
# 6          11   48668.131868   -7831.868132
# 7          12   51136.986301    2468.854433
# 8          13   35748.400000  -15388.586301
# 9          14   35655.721311     -92.678689
# 10         15   31793.333333   -3862.387978
# 11         16   22267.857143   -9525.476190
# 12         17   34289.285714   12021.428571
# 13         18   24927.586207   -9361.699507
# 14         19   23380.000000   -1547.586207
# 15         20   16978.571429   -6401.428571
# 16         21   15100.000000   -1878.571429
# 17         22    8000.000000   -7100.000000
# 18         23   20666.666667   12666.666667
# 19         24   40000.000000   19333.333333
# ...

# %%
# 14. which bike names are priced significantly above the average price for their manufacturing year?

# Step 1: Group by year and calculate average price and standard deviation
year_stats = df.groupby('year')['selling_price'].agg(['mean', 'std']).reset_index()
year_stats.rename(columns={'mean': 'average_price', 'std': 'price_std'}, inplace=True)

# Step 2: Merge statistics back to the original DataFrame without duplicate column names
df = df.merge(year_stats, on='year', suffixes=('', '_y'))

# Step 3: Define the threshold (1 standard deviation above the average)
df['above_threshold'] = df['selling_price'] > (df['average_price'] + df['price_std'])

# Step 4: Filter bikes priced significantly above average
significantly_priced_bikes = df[df['above_threshold']][['name', 'year', 'selling_price']]

# Display results
print(significantly_priced_bikes)
# Out:
#                                      name  year  selling_price
# 2     Royal Enfield Classic Gunmetal Grey  2018         150000
# 7    Royal Enfield Bullet 350 [2007-2011]  2008         180000
# 13                          Yamaha YZF R3  2019         365000
# 18    Royal Enfield Classic Gunmetal Grey  2018         150000
# 24          Royal Enfield Thunderbird 350  2016         110000
# ..                                    ...   ...            ...
# 976             Royal Enfield Classic 350  2015         110000
# 979             Royal Enfield Thunder 500  2015         105000
# 983             Royal Enfield Classic 350  2015         100000
# 984             Royal Enfield Classic 500  2014          95000
# 985             Royal Enfield Classic 500  2011          90000
#
# [125 rows x 3 columns]

# %%
# 15 Develop a correlation matrix for numeric columns and visualize is using a heatmap.

corr = df.corr(numeric_only = True)
corr
# Out:
#                    selling_price      year  km_driven  ex_showroom_price  \
# selling_price           1.000000  0.402188  -0.212937           0.918583
# year                    0.402188  1.000000  -0.288675           0.126378
# km_driven              -0.212937 -0.288675   1.000000          -0.122011
# ex_showroom_price       0.918583  0.126378  -0.122011           1.000000
# bikes_age              -0.402188 -1.000000   0.288675          -0.126378
# age                    -0.402188 -1.000000   0.288675          -0.126378
# average_price_x         0.501140  0.802547  -0.309402           0.146598
# price_std_x             0.353638  0.576350  -0.243017           0.132295
# above_threshold         0.577832  0.056858  -0.094711           0.601946
# average_price_y         0.501140  0.802547  -0.309402           0.146598
# price_std_y             0.353638  0.576350  -0.243017           0.132295
# average_price           0.501140  0.802547  -0.309402           0.146598
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(corr, annot = True, cmap = 'coolwarm' , fmt = '.2f')
# Out:
# <Axes: >
